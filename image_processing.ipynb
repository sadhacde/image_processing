# %%
import pandas as pd
import numpy as np
from glob import glob
import cv2
import matplotlib.pylab as plt

# %%
image_files = glob("images/*.jpg")

# %%
image_mpl = plt.imread(image_files[0])
image_cv2 = cv2.imread(image_files[0])

# %%
image_mpl.shape, image_cv2.shape # height, width, channels
# Out:
# ((1667, 2500, 3), (1667, 2500, 3))

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(image_mpl)
ax.axis('off')
plt.show()

# %% [raw]
# image channels: red x green x blue
# cv2 - BGR
# matplotlib - RGB
